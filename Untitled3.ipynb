# %%
from propagation.HAN_demo.HAN import HAN, predict_HAN, train_HAN, Vectorizer, segmenter
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/cz/mf6k7s456v95hf4y3g4lyfz40000gn/T/ipykernel_12111/3314425054.py in <module>
# ----> 1 from propagation.HAN_demo.HAN import HAN, predict_HAN, train_HAN, Vectorizer, segmenter
#
# ~/PycharmProjects/fake_news_detection/fake_news_detection/propagation/HAN_demo/HAN/__init__.py in <module>
#       2 from propagation.HAN_demo.HAN.utils.predict import predict_HAN
#       3 from propagation.HAN_demo.HAN.utils.train import train_HAN
# ----> 4 from propagation.HAN_demo.HAN.utils.preprocess import Vectorizer
#       5 from propagation.HAN_demo.HAN.utils.preprocess import segmenter
#
# ~/PycharmProjects/fake_news_detection/fake_news_detection/propagation/HAN_demo/HAN/utils/preprocess.py in <module>
#       4 from collections import Counter
#       5 from typing import List, Iterator
# ----> 6 nlp = spacy.load("en_core_web_sm")
# ...

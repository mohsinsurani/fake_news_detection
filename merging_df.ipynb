# %%
import pandas as pd

# %%
politifact_df = pd.read_csv('politifact.csv')

# %%
tweets_politifact_df = pd.read_csv('tweets_politifact.csv')

# %%
politifact_df.shape
# Out:
# (828, 7)

# %%
tweets_politifact_df.shape
# Out:
# (646, 2)

# %%
politifact_df.head()
# Out:
#                                                               text  \
# id
# politifact14238  Police in Vernal Heights, Florida, arrested 3-...
# politifact14836                                                NaN
# politifact14207  Keanu Reeves Shook The World With Another POWE...
# politifact14831                                                NaN
# politifact14469  \n\nPresident Obama, alongside his family, ser...
#
#                                                              title  \
# id
# politifact14238  Cannibals Arrested in Florida Claim Eating Hum...
# politifact14836                            houstonchronicle-tv.com
# politifact14207  Keanu Reeves Shook The World With Another POWE...
# politifact14831                                    Contact Support
# politifact14469  First family visits D.C. shelter, highlights h...
#
#                                                            top_img  \
# id
# politifact14238  http://dailybuzzlive.com/wp-content/uploads/Ca...
# ...

# %%
politifact_df = politifact_df.set_index('id')
tweets_politifact_df = tweets_politifact_df.set_index('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cz/mf6k7s456v95hf4y3g4lyfz40000gn/T/ipykernel_19831/3691647726.py in <module>
# ----> 1 politifact_df = politifact_df.set_index('id')
#       2 tweets_politifact_df = tweets_politifact_df.set_index('id')
#
# ~/opt/miniconda3/envs/myenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/miniconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# ...

# %%
politifact_df.id.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cz/mf6k7s456v95hf4y3g4lyfz40000gn/T/ipykernel_19831/1126361769.py in <module>
# ----> 1 politifact_df.id.dtype
#
# ~/opt/miniconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'id'

# %%
tweets_politifact_df.id.dtype
# Out:
# dtype('O')

# %%
tweets_politifact_df.head()
# Out:
#                 id                                              tweet
# 0  politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1  politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 2  politifact14831  [{'text': 'Breaking: Woman Says She Was Offere...
# 3  politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4  politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...

# %%
# df1 = pd.concat(politifact_df, tweets_politifact_df, axis=1, join='inner')
# df1 = tweets_politifact_df.join(politifact_df)
df1 = tweets_politifact_df.join(politifact_df, on='id', how='left')

# %%
df1.head()
# Out:
#                 id                                              tweet  \
# 0  politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1  politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 2  politifact14831  [{'text': 'Breaking: Woman Says She Was Offere...
# 3  politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4  politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
#
#                                                 text  \
# 0  Police in Vernal Heights, Florida, arrested 3-...
# 1  Keanu Reeves Shook The World With Another POWE...
# 2                                                NaN
# 3  \n\nPresident Obama, alongside his family, ser...
# 4  A senior Iranian cleric and member of parliame...
#
#                                                title  \
# 0  Cannibals Arrested in Florida Claim Eating Hum...
# 1  Keanu Reeves Shook The World With Another POWE...
# 2                                    Contact Support
# ...

# %%
df1.shape
# Out:
# (650, 9)

# %%
df1
# Out:
#                   id                                              tweet  \
# 0    politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1    politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 2    politifact14831  [{'text': 'Breaking: Woman Says She Was Offere...
# 3    politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4    politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
# ..               ...                                                ...
# 641  politifact12944  [{'text': 'Man sentenced to life in prison in ...
# 642  politifact11399  [{'text': 'Responsibilities require you to be ...
# 643   politifact4720  [{'text': "Flashback 2007: Romney's #ProLife C...
# 644   politifact8119  [{'text': 'In an interview with Bloomberg tele...
# 645   politifact1067  [{'text': 'Canoe.ca\n\n\'Person of Interest\' ...
#
#                                                   text  \
# ...

# %%
# df1[df1['tweet'] == ''].index
# df2 = df1[df1.duplicated()]
df1.drop_duplicates(subset=['text', "title"], keep=False)
# Out:
#                   id                                              tweet  \
# 0    politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1    politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 2    politifact14831  [{'text': 'Breaking: Woman Says She Was Offere...
# 3    politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4    politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
# ..               ...                                                ...
# 638   politifact6842  [{'text': "U.S. Asian Policy: America's Securi...
# 639  politifact11709  [{'text': 'Heading to Democratic presidential ...
# 640    politifact746  [{'text': 'Michelle Obama is ramping up her ef...
# 642  politifact11399  [{'text': 'Responsibilities require you to be ...
# 645   politifact1067  [{'text': 'Canoe.ca\n\n\'Person of Interest\' ...
#
#                                                   text  \
# ...

# %%
df1.shape
# Out:
# (650, 9)

# %%
df1[df1["target"] == 0]
# Out:
#                   id                                              tweet  \
# 0    politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1    politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 2    politifact14831  [{'text': 'Breaking: Woman Says She Was Offere...
# 3    politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4    politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
# ..               ...                                                ...
# 344  politifact14085  [{'text': 'BREAKING: Bill O’Reilly In Critical...
# 345  politifact15533  [{'text': 'Burka Clad Woman Runs Over Baby, Ge...
# 346  politifact14071  [{'text': 'Lindsey Graham Threatens To Convert...
# 382  politifact14920  [{'text': 'The U.S. Code of Federal Regulation...
# 566  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
#
#                                                   text  \
# ...

# %%
df2
# Out:
#                   id                                              tweet  \
# 247  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
# 247  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
# 566  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
# 566  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
#
#                                                   text  \
# 247  Full text: Jeff Flake on Trump speech transcri...
# 247  Full text: Jeff Flake on Trump speech transcri...
# 566  Full text: Jeff Flake on Trump speech transcri...
# 566  Full text: Jeff Flake on Trump speech transcri...
#
#                                                 title  \
# 247  Full text: Jeff Flake on Trump speech transcript
# 247  Full text: Jeff Flake on Trump speech transcript
# 566  Full text: Jeff Flake on Trump speech transcript
# 566  Full text: Jeff Flake on Trump speech transcript
#
# ...

# %%
# df_new = df1.drop(df1[(df1['text'] == NaN) | (df1['top_img'] == NaN)].index)
df_new = df1[df1['text'].notna()]
df_new = df_new[df_new['top_img'].notna()]

# %%
df_new
# Out:
#                   id                                              tweet  \
# 0    politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1    politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 3    politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4    politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
# 5    politifact13687  [{'text': 'Mike Pence: “Allowing Rape Victims ...
# ..               ...                                                ...
# 641  politifact12944  [{'text': 'Man sentenced to life in prison in ...
# 642  politifact11399  [{'text': 'Responsibilities require you to be ...
# 643   politifact4720  [{'text': "Flashback 2007: Romney's #ProLife C...
# 644   politifact8119  [{'text': 'In an interview with Bloomberg tele...
# 645   politifact1067  [{'text': 'Canoe.ca\n\n\'Person of Interest\' ...
#
#                                                   text  \
# ...

# %%
df_new.to_csv("poli_final.csv")

# %%
df_new
# Out:
#                   id                                              tweet  \
# 0    politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1    politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 3    politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4    politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
# 5    politifact13687  [{'text': 'Mike Pence: “Allowing Rape Victims ...
# ..               ...                                                ...
# 641  politifact12944  [{'text': 'Man sentenced to life in prison in ...
# 642  politifact11399  [{'text': 'Responsibilities require you to be ...
# 643   politifact4720  [{'text': "Flashback 2007: Romney's #ProLife C...
# 644   politifact8119  [{'text': 'In an interview with Bloomberg tele...
# 645   politifact1067  [{'text': 'Canoe.ca\n\n\'Person of Interest\' ...
#
#                                                   text  \
# ...

# %%
df_new[df_new["target"] == 0]
# Out:
#                   id                                              tweet  \
# 0    politifact14238  [{'text': 'Cannibals Arrested in Florida Claim...
# 1    politifact14207  [{'text': 'Keanu Reeves Shock The World With A...
# 3    politifact14469  [{'text': 'First family visits D.C. shelter, h...
# 4    politifact15570  [{'text': 'Iranian Official Drops Bombshell: O...
# 5    politifact13687  [{'text': 'Mike Pence: “Allowing Rape Victims ...
# ..               ...                                                ...
# 343  politifact15534  [{'text': 'NASA Announced That It Communicated...
# 344  politifact14085  [{'text': 'BREAKING: Bill O’Reilly In Critical...
# 345  politifact15533  [{'text': 'Burka Clad Woman Runs Over Baby, Ge...
# 382  politifact14920  [{'text': 'The U.S. Code of Federal Regulation...
# 566  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
#
#                                                   text  \
# ...

# %%
df_new[df_new["target"] == 1]
# Out:
#                   id                                              tweet  \
# 46   politifact14920  [{'text': 'Title 14, Section 1211 of the Code ...
# 247  politifact14940  [{'text': 'Partial Transcript: Jeff Flake’s Sp...
# 347  politifact12104  [{'text': 'In Chinese universities, students s...
# 350  politifact12755  [{'text': 'Pastors To Protest IRS Rules on Pol...
# 352    politifact539  [{'text': 'Press Coverage of Food Bloggers Mee...
# ..               ...                                                ...
# 641  politifact12944  [{'text': 'Man sentenced to life in prison in ...
# 642  politifact11399  [{'text': 'Responsibilities require you to be ...
# 643   politifact4720  [{'text': "Flashback 2007: Romney's #ProLife C...
# 644   politifact8119  [{'text': 'In an interview with Bloomberg tele...
# 645   politifact1067  [{'text': 'Canoe.ca\n\n\'Person of Interest\' ...
#
#                                                   text  \
# ...

# %%
import pickle
file_name_pickle = "/Users/admin/PycharmProjects/fake_news_detection/fake_news_detection/pickle/get_emotion_of_tweet.pkl"
emotion_arr = pickle.load(open(file_name_pickle, "rb"))

# %%
emotion_arr[1]
# Out:
# {'anger': 0.0,
#  'anticipation': 0.0,
#  'disgust': 0.0,
#  'fear': 0.0,
#  'joy': 0.0,
#  'negative': 0.10714285714285714,
#  'positive': 0.0,
#  'sadness': 0.10714285714285714,
#  'surprise': 0.03571428571428571,
#  'trust': 0.03571428571428571}

# %%
file_name_sent = "/Users/admin/PycharmProjects/fake_news_detection/fake_news_detection/pickle/get_sentiment_of_tweet.pkl"
sentn_arr = pickle.load(open(file_name_sent, "rb"))
sentn_arr[1]
# Out:
# {'neg': 0.09324000000000002,
#  'neu': 0.76488,
#  'pos': 0.14187999999999998,
#  'compound': 0.2788279999999999}
